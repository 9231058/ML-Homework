# %% [markdown]
# In The Name of God
#
# Parham Alvani (98131910)
#
# The following document contains the practical section of Homework-1.

# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')

# %%
dataset
# Out:
#          x      y
# 0    0.010  0.958
# 1    0.014  1.034
# 2    0.018  1.109
# 3    0.022  1.094
# 4    0.027  1.104
# ..     ...    ...
# 235  0.983 -0.975
# 236  0.988 -0.903
# 237  0.992 -1.331
# 238  0.996 -0.913
# 239  1.000 -1.019
#
# [240 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
_, ax1 = plt.subplots()
dataset.plot(x='x', y='y', ax=ax1)

# %% [markdown]
# In the following section we want to compare between multiple values of *alpha* for *n = 10* and *steps = 150*. The best value for *alpha* around 1. we demostrate hypothesis function for `[0.1, 1, 1.5]`.
#
# As you may see the following diagram I think alpha = 1, n = 10 and steps = 150 is better than other settings for given dataset.

# %% [markdown]
# #### alpha = 0.1

# %%
import numpy as np
import regression

_, ax2 = plt.subplots()
_, ax3 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=0.1, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax2.plot(x, y, 'r--', x, yh, 'b--')

ax3.plot(range(150), mse)

# %% [markdown]
# #### alpha = 1

# %%
_, ax4 = plt.subplots()
_, ax5 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax4.plot(x, y, 'r--', x, yh, 'b--')

ax5.plot(range(150), mse)

# %% [markdown]
# #### alpha = 1.115

# %%
_, ax6 = plt.subplots()
_, ax7 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1.115, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax6.plot(x, y, 'r--', x, yh, 'b--')

ax7.plot(range(150), mse)

# %% [markdown]
# In the following section we want to compare between multiple values of *steps* for *n = 10* and *alpha = 1.115*. we demostrate hypothesis function for `[100, 150, 200]`.

# %% [markdown]
# #### steps = 100

# %%
_, ax8 = plt.subplots()
_, ax9 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1.115, steps=100, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax8.plot(x, y, 'r--', x, yh, 'b--')

ax9.plot(range(100), mse)

# %% [markdown]
# #### steps = 150

# %%
_, ax10 = plt.subplots()
_, ax11 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1.115, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax10.plot(x, y, 'r--', x, yh, 'b--')

ax11.plot(range(150), mse)

# %% [markdown]
# #### steps = 200

# %%
_, ax12 = plt.subplots()
_, ax13 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1.115, steps=200, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax12.plot(x, y, 'r--', x, yh, 'b--')

ax13.plot(range(200), mse)

# %% [markdown]
# In the following section we want to compare between multiple values of *degree* for *steps = 150* and *alpha = 1.115*. we demostrate hypothesis function for `[10, 15, 20]`.

# %% [markdown]
# #### degree = 10

# %%
_, ax14 = plt.subplots()
_, ax15 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=10, alpha=1.115, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax14.plot(x, y, 'r--', x, yh, 'b--')

ax15.plot(range(150), mse)

# %% [markdown]
# #### degree = 12

# %%
_, ax16 = plt.subplots()
_, ax17 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=12, alpha=1.115, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax16.plot(x, y, 'r--', x, yh, 'b--')

ax17.plot(range(150), mse)

# %% [markdown]
# #### degree 15

# %%
_, ax18 = plt.subplots()
_, ax19 = plt.subplots()
h, mse = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=15, alpha=1.115, steps=150, lmb=0)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax18.plot(x, y, 'r--', x, yh, 'b--')

ax19.plot(range(150), mse)

# %% [markdown]
# I think using a feature with less variation may cause better results.

# %% [markdown]
# In the following diagram we compare coefficient of `x` with different values of lambda.

# %%
_, ax20 = plt.subplots()

coefficient = []
lmbs = []

for lmb in [0, 1, 5, 10]:
    h, _ = regression.regression(data={d[0]: d[1] for d in dataset.values}, n=2, alpha=1, steps=100, lmb=lmb)
    lmbs.append(lmb)
    coefficient.append(h[1])

ax20.plot(lmbs, coefficient)

# %%
_, ax21 = plt.subplots()

h = regression.regression_with_normal_equation(data={d[0]: d[1] for d in dataset.values}, n=10)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax21.plot(x, y, 'r--', x, yh, 'b--')

# %%
_, ax21 = plt.subplots()

h = regression.regression_with_normal_equation(data={d[0]: d[1] for d in dataset.values}, n=5)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax21.plot(x, y, 'r--', x, yh, 'b--')

# %%
_, ax21 = plt.subplots()

h = regression.regression_with_normal_equation(data={d[0]: d[1] for d in dataset.values}, n=3)

x = [d[0] for d in dataset.values]
y = [d[1] for d in dataset.values]
yh = [np.polynomial.polynomial.polyval(x, h) for x in x]

ax21.plot(x, y, 'r--', x, yh, 'b--')
